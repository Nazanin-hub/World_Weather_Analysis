# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("C:\\Users\\asus\\World_Weather_Analysis\\Vacation_Search\\WeatherPy_vacation.csv")
vacation_df.head(30)
# Out:
#     City_ID            City Country  Max Temp Current Description    Lat  \
# 0         6  Saint-Philippe      RE     75.20       broken clouds -21.36
# 1        12        Bengkulu      ID     75.96          light rain  -3.80
# 2        13          Atuona      PF     77.99          light rain  -9.80
# 3        18        Lorengau      PG     80.26       broken clouds  -2.02
# 4        21       Kununurra      AU     78.80       broken clouds -15.77
# 5        24         Rikitea      PF     75.11       broken clouds -23.12
# 6        32     Saint Marys      US     82.00       broken clouds  30.73
# 7        36         Samarai      PG     80.83       broken clouds -10.62
# 8        41          Zaraza      VE     85.59          light rain   9.35
# 9        47           Tocok      PH     78.80       broken clouds  15.75
# 10       55     Balaipungut      ID     75.97          light rain   1.05
# 11       56        Acajutla      SV     82.40    scattered clouds  13.59
# 12       61    Quatre Cocos      MU     75.20       broken clouds -20.21
# 13       62      Batticaloa      LK     80.49       moderate rain   7.71
# 14       65         Wanning      CN     77.31          light rain  18.80
# 15       73   San Cristobal      VE     86.00    scattered clouds   7.77
# 16       79  Cabo San Lucas      MX     82.99           clear sky  22.89
# 17       82   Cockburn Town      TC     86.00       broken clouds  21.46
# 18       83         Vaitape      PF     80.51       broken clouds -16.52
# 19       85      Santa Rosa      PH     81.00    scattered clouds  14.31
# 20       86          Jibuti      DJ     84.20           clear sky  11.50
# 21       88          Castro      BR     77.95          few clouds -24.79
# 22       92         Sibolga      ID     76.89           clear sky   1.74
# 23       95   Bambanglipuro      ID     76.59     overcast clouds  -7.95
# 24       96          Kupang      ID     80.29    scattered clouds -10.17
# 25       99         Cayenne      GF     89.60           clear sky   4.93
# 26      107       Kavaratti      IN     82.08    scattered clouds  10.57
# 27      108     Black River      JM     87.80          few clouds  18.03
# 28      110            Nata      PA     84.20          few clouds   8.33
# 29      112        Victoria      HK     77.00     overcast clouds  22.29
#
#        Lng                     Hotel Name
# 0    55.77   Chambres d'hôte "La Trinité"
# 1   102.27           Grage Hotel Bengkulu
# 2  -139.03                    Villa Enata
# 3   147.27     Lorengau Harbourside Hotel
# 4   128.73                Hotel Kununurra
# 5  -134.97                 Pension Maro'i
# 6   -81.55              Spencer House Inn
# 7   150.67                      Nuli Sapi
# 8   -65.32                   Hotel Zaraza
# 9   120.30  Dandan’s Garden & Farm Resort
# 10  101.28              Swee Ann Homestay
# 11  -89.83                          Stop.
# 12   57.76  Emeraude Beach Attitude Hotel
# 13   81.69         Grand Star Guest House
# 14  110.40                 Paradise Hotel
# 15  -72.22                       Pirineos
# 16 -109.91         Hotel Tesoro Los Cabos
# 17  -71.14             Osprey Beach Hotel
# 18 -151.75           Conrad Bora Bora Nui
# 19  121.11     Erlyn’s Sta Rosa City Home
# 20   42.50        Orchid Main Camp Goubet
# 21  -50.01                 CHACARA BAILLY
# 22   98.78    Hotel Syariah CN Darussalam
# 23  110.28                     Puri Brata
# 24  123.58    Sylvia Hotel Premier Kupang
# 25  -52.33                Hôtel Le Dronmi
# 26   72.64  Hotels in Lakshadweep Islands
# 27  -77.85       Idlers' Rest Beach Hotel
# 28  -80.52       Cabañas Estancia Bayamon
# 29  114.16             Mini Hotel Central

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and<dd>{Max Temp} °F</dd>
</dl>
"""


# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"]== "Rincon"]
vacation_end = vacation_df.loc[vacation_df["City"]== "Rincon"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]== "Seminole"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]== "Iberia"]
vacation_stop3 = vacation_df.loc[vacation_df["City"]== "Russell"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

start = vacation_start[["Lat", "Lng"]].to_numpy()[0]
print(start)
end = vacation_end[["Lat", "Lng"]].to_numpy()[0]
print(end)
stop1 = vacation_stop1[["Lat", "Lng"]].to_numpy()[0]
print(stop1)
stop2 = vacation_stop2[["Lat", "Lng"]].to_numpy()[0]
print(stop2)
stop3 = vacation_stop3[["Lat", "Lng"]].to_numpy()[0]
print(stop3)
# Out:
# [ 32.3  -81.24]
# [ 32.3  -81.24]
# [ 28.71 -81.21]
# [ 29.95 -91.75]
# [ 32.35 -85.2 ]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer( start, end, waypoints=[stop1,stop2,stop3], travel_mode="DRIVING" )
        
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_end,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID      City Country  Max Temp Current Description    Lat    Lng  \
# 0      365    Rincon      US      82.4       broken clouds  32.30 -81.24
# 1      365    Rincon      US      82.4       broken clouds  32.30 -81.24
# 2      146  Seminole      US      86.0    scattered clouds  28.71 -81.21
# 3      310    Iberia      US      81.0     overcast clouds  29.95 -91.75
# 4      496   Russell      US      79.0     overcast clouds  32.35 -85.20
#
#                       Hotel Name
# 0          Bent tree subdivision
# 1          Bent tree subdivision
# 2  Ono Hot Dog Cart and Catering
# 3           back to back rv park
# 4                           Macs

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and<dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
